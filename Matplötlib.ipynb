# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnysunil611/CodeAlpha_Attendance_Management_System/blob/main/Matpl%C3%B6tlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style

# %%
#Scatter Plöt

x=np.random.rand(1000)
y=np.random.rand(1000)

plt.scatter(x,y,color='green',marker='*', alpha=0.3)

# %%
#Line Plöt

years = [2000 + x for x in range(10)]
salary = [20,30,40,10,90,40,20,60,70,20,]

print(years)
print(salary)

plt.plot(years,salary, c='red',lw=5,linestyle='--')
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]
# [20, 30, 40, 10, 90, 40, 20, 60, 70, 20]

# %%
#Bar Chart

titles = [4,0,5,1,0,1,3,9]
ipl_team = ["CSK","RCB","MI","GT","PSK","DC","RR","LSG"]

print(titles)
print(ipl_team)

plt.bar(ipl_team,titles, color='red',align='edge')
# Out:
# [4, 0, 5, 1, 0, 1, 3, 9]
# ['CSK', 'RCB', 'MI', 'GT', 'PSK', 'DC', 'RR', 'LSG']
# <BarContainer object of 8 artists>

# %%
#Histogram

ages = np.random.normal(6,2,100)

plt.hist(ages, bins=50,color='g',cumulative=True)
# Out:
# (array([  1.,   2.,   3.,   5.,   6.,   6.,   9.,  10.,  10.,  12.,  13.,
#          15.,  20.,  22.,  24.,  26.,  27.,  28.,  31.,  34.,  37.,  45.,
#          47.,  53.,  55.,  59.,  63.,  67.,  70.,  74.,  78.,  80.,  85.,
#          88.,  88.,  89.,  90.,  93.,  93.,  94.,  94.,  94.,  96.,  97.,
#          97.,  98.,  98.,  98.,  98., 100.]),
#  array([ 1.57950274,  1.76420574,  1.94890873,  2.13361172,  2.31831472,
#          2.50301771,  2.68772071,  2.8724237 ,  3.0571267 ,  3.24182969,
#          3.42653268,  3.61123568,  3.79593867,  3.98064167,  4.16534466,
#          4.35004765,  4.53475065,  4.71945364,  4.90415664,  5.08885963,
#          5.27356262,  5.45826562,  5.64296861,  5.82767161,  6.0123746 ,
#          6.1970776 ,  6.38178059,  6.56648358,  6.75118658,  6.93588957,
#          7.12059257,  7.30529556,  7.48999855,  7.67470155,  7.85940454,
#          8.04410754,  8.22881053,  8.41351353,  8.59821652,  8.78291951,
# ...

# %%
titles = [30,90,50,20,10]
ipl_team = ["cycle","bike","train","flight","zet"]
explodes = [0,0,0,0,1]
style.use("ggplot")

plt.pie(titles, labels=ipl_team,explode=explodes, autopct="%.2f%%",pctdistance=0.6, startangle=180)
plt.legend(title="transport")

# %%
titles = np.random.random(100)
plt.boxplot(titles)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bc8cd2a5110>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7bc8cd316490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7bc8cd2a52d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bc8cd314e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bc8cd2a5ad0>],
#  'means': []}

# %%
#Line Plöt

years = [2000 + x for x in range(10)]
runs = [100,120,130,150,170,180,200,230,250,280]

style.use("ggplot")

plt.plot(years,runs, c='blue')
plt.title("No. of Runs in IPL increasing every year")
plt.xlabel("Year",fontsize=10)
plt.ylabel("Runs")
plt.legend()
# Out:
# <ipython-input-63-424e104c8932>:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#SUB Plotting

x=np.random.rand(1000)

fig, axs = plt.subplots(2,2)

axs[0,0].plot(x,np.sin(x))
axs[0,0].set_title("Log_Graph")

axs[0,1].plot(x,np.cos(x))
axs[0,1].set_title("Log_Graph")

axs[1,0].plot(x,np.tan(x))
axs[1,0].set_title("Log_Graph")

axs[1,1].plot(x,np.log(x))
axs[1,1].set_title("Log_Graph")

plt.savefig("4plot.png", dpi=400)

# %%
#3D plots


x = np.arange(1,10,0.5)
y = np.arange(10,20,0.5)

X,Y = np.meshgrid(x,y)

Z=np.sin(X)*np.cos(Y)

ax=plt.axes(projection="3d")

#ax.scatter(x,y,z)

ax.plot_surface(X,Y,Z)
ax.set_title("3D Plot")
ax.set_xlabel("X-Axis")
ax.set_ylabel("Y-Axis")
ax.set_zlabel("Z-Axis")
# Out:
# Text(0.5, 0, 'Z-Axis')

# %%
#ANIMATIONS

import random

h_t=[0,0]

for _ in range(1000000):
  h_t[random.randint(0,1)]+=1
  plt.bar(["Head,Tails"],h_t,color=["Blue","Red"])
  plt.pause(0.001)

# %%
##SEA BORN
import pandas as pd
import seaborn as sns
#ed = pd.read_csv("International_Education_Costs.csv")
#ed.head(10)


tips = sns.load_dataset("tips")
tips.head(10)

sns.histplot(tips["tip"],kde=True,bins=10)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.barplot(x="sex",y="tip",data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x="day",y="tip",data=tips, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day",y="tip",data=tips, hue="sex",dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.scatterplot(x="tip",y="total_bill",data=tips,hue="sex",size="size")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex")

# %%
titanic = sns.load_dataset("titanic")
sns.pairplot(titanic.select_dtypes(["number"]),hue="pclass")

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
n_d=titanic.select_dtypes(["number"])
c_m = n_d.corr()
sns.heatmap(c_m,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# # New section
